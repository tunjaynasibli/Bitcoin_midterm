# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("immo_data.csv")

# %%
data.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date'],
#       dtype='object')

# %%
deleted_list = [ "heatingType", "telekomTvOffer", "telekomHybridUploadSpeed", "picturecount", "pricetrend", 
                "telekomUploadSpeed", "scoutId", "noParkSpaces", "firingTypes", "geo_bln", "yearConstructedRange",
               "houseNumber", "geo_krs","condition", "interiorQual", "petsAllowed","street", "streetPlain", "lift", 
                "baseRentRange","geo_plz", "thermalChar", "floor", "numberOfFloors", "noRoomsRange", 
                "livingSpaceRange", "regio3", "description", "facilities", "heatingCosts",
                "energyEfficiencyClass", "lastRefurbish",
               "electricityBasePrice", "electricityKwhPrice"]

# %%
data.drop(deleted_list, axis=1, inplace=True)

# %%
##Berlin_data = data[data["regio2"] == "Berlin" ]
##Hamburg_data = data[data["regio2"] == "Hamburg" ]
##Munchen_data = data[data["regio2"] == "München" ]

# %%
'''
def nan_counter(df):
    remaining_nan = {}
    for column in df.columns:
        remaining_nan[column] = df[column][df[column].isna() == True].size
    return remaining_nan
'''
# Out:
# '\ndef nan_counter(df):\n    remaining_nan = {}\n    for column in df.columns:\n        remaining_nan[column] = df[column][df[column].isna() == True].size\n    return remaining_nan\n'

# %%
## We check the NaN values and we decided to fix them.
###nan_counter(Hamburg_data)

# %%
## We decided that values more than 1000 for serviceCharge are outliers so made filter.
##Hamburg_data = Hamburg_data[Hamburg_data["serviceCharge"] < 1000]

# %%
##Hamburg_data.shape

# %%
##Hamburg_data.serviceCharge.hist()

# %%
data
# Out:
#                      regio1  serviceCharge  newlyConst  balcony  totalRent  \
# 0       Nordrhein_Westfalen         245.00       False    False      840.0
# 1           Rheinland_Pfalz         134.00       False     True        NaN
# 2                   Sachsen         255.00        True     True     1300.0
# 3                   Sachsen          58.15       False     True        NaN
# 4                    Bremen         138.00       False     True      903.0
# ...                     ...            ...         ...      ...        ...
# 268845               Bayern          90.00       False     True      910.0
# 268846               Hessen         220.00       False     True     1150.0
# 268847               Hessen         220.00       False     True      930.0
# 268848  Nordrhein_Westfalen         175.00        True     True     1015.0
# 268849               Hessen         315.00       False     True        NaN
#
#         yearConstructed  hasKitchen  cellar  baseRent  livingSpace  \
# 0                1965.0       False    True     595.0        86.00
# 1                1871.0       False   False     800.0        89.00
# 2                2019.0       False    True     965.0        83.80
# 3                1964.0       False   False     343.0        58.15
# 4                1950.0       False   False     765.0        84.97
# ...                 ...         ...     ...       ...          ...
# 268845           2016.0       False    True     820.0        90.00
# 268846           1983.0        True   False     930.0       115.00
# 268847           1965.0       False    True     650.0        95.00
# 268848           2019.0       False    True     840.0        70.00
# 268849           1972.0        True    True     935.0        77.00
#
#           typeOfFlat  noRooms  garden                   regio2   date
# 0       ground_floor      4.0    True                 Dortmund  May19
# 1       ground_floor      3.0   False        Rhein_Pfalz_Kreis  May19
# 2          apartment      3.0   False                  Dresden  Oct19
# 3              other      3.0   False      Mittelsachsen_Kreis  May19
# 4          apartment      3.0   False                   Bremen  Feb20
# ...              ...      ...     ...                      ...    ...
# 268845   roof_storey      3.0   False  Weilheim_Schongau_Kreis  Feb20
# 268846     apartment      3.5   False         Bergstraße_Kreis  May19
# 268847     apartment      4.0    True   Limburg_Weilburg_Kreis  Feb20
# 268848     apartment      2.0   False                     Köln  May19
# 268849     apartment      3.0   False        Frankfurt_am_Main  Feb20
#
# [268850 rows x 15 columns]

# %%
##df.dropna(subset = ["column2"], inplace=True)
data.dropna(subset = ["totalRent"], inplace=True)

# %%
data
# Out:
#                      regio1  serviceCharge  newlyConst  balcony  totalRent  \
# 0       Nordrhein_Westfalen          245.0       False    False     840.00
# 2                   Sachsen          255.0        True     True    1300.00
# 4                    Bremen          138.0       False     True     903.00
# 6                   Sachsen           70.0       False    False     380.00
# 7                    Bremen           88.0       False     True     584.25
# ...                     ...            ...         ...      ...        ...
# 268844  Nordrhein_Westfalen           80.0       False    False     670.00
# 268845               Bayern           90.0       False     True     910.00
# 268846               Hessen          220.0       False     True    1150.00
# 268847               Hessen          220.0       False     True     930.00
# 268848  Nordrhein_Westfalen          175.0        True     True    1015.00
#
#         yearConstructed  hasKitchen  cellar  baseRent  livingSpace  \
# 0                1965.0       False    True    595.00        86.00
# 2                2019.0       False    True    965.00        83.80
# 4                1950.0       False   False    765.00        84.97
# 6                   NaN       False    True    310.00        62.00
# 7                1959.0       False    True    452.25        60.30
# ...                 ...         ...     ...       ...          ...
# 268844              NaN       False   False    590.00        85.00
# 268845           2016.0       False    True    820.00        90.00
# 268846           1983.0        True   False    930.00       115.00
# 268847           1965.0       False    True    650.00        95.00
# 268848           2019.0       False    True    840.00        70.00
#
#           typeOfFlat  noRooms  garden                   regio2   date
# 0       ground_floor      4.0    True                 Dortmund  May19
# 2          apartment      3.0   False                  Dresden  Oct19
# 4          apartment      3.0   False                   Bremen  Feb20
# 6                NaN      2.0    True      Mittelsachsen_Kreis  Feb20
# 7       ground_floor      3.0   False                   Bremen  Feb20
# ...              ...      ...     ...                      ...    ...
# 268844   roof_storey      3.0   False                    Essen  Feb20
# 268845   roof_storey      3.0   False  Weilheim_Schongau_Kreis  Feb20
# 268846     apartment      3.5   False         Bergstraße_Kreis  May19
# 268847     apartment      4.0    True   Limburg_Weilburg_Kreis  Feb20
# 268848     apartment      2.0   False                     Köln  May19
#
# [228333 rows x 15 columns]

# %%
data.dropna(subset = ["livingSpace"], inplace=True)

# %%
data.dropna(subset = ["date"], inplace=True)

# %%
data
# Out:
#                      regio1  serviceCharge  newlyConst  balcony  totalRent  \
# 0       Nordrhein_Westfalen          245.0       False    False     840.00
# 2                   Sachsen          255.0        True     True    1300.00
# 4                    Bremen          138.0       False     True     903.00
# 6                   Sachsen           70.0       False    False     380.00
# 7                    Bremen           88.0       False     True     584.25
# ...                     ...            ...         ...      ...        ...
# 268844  Nordrhein_Westfalen           80.0       False    False     670.00
# 268845               Bayern           90.0       False     True     910.00
# 268846               Hessen          220.0       False     True    1150.00
# 268847               Hessen          220.0       False     True     930.00
# 268848  Nordrhein_Westfalen          175.0        True     True    1015.00
#
#         yearConstructed  hasKitchen  cellar  baseRent  livingSpace  \
# 0                1965.0       False    True    595.00        86.00
# 2                2019.0       False    True    965.00        83.80
# 4                1950.0       False   False    765.00        84.97
# 6                   NaN       False    True    310.00        62.00
# 7                1959.0       False    True    452.25        60.30
# ...                 ...         ...     ...       ...          ...
# 268844              NaN       False   False    590.00        85.00
# 268845           2016.0       False    True    820.00        90.00
# 268846           1983.0        True   False    930.00       115.00
# 268847           1965.0       False    True    650.00        95.00
# 268848           2019.0       False    True    840.00        70.00
#
#           typeOfFlat  noRooms  garden                   regio2   date
# 0       ground_floor      4.0    True                 Dortmund  May19
# 2          apartment      3.0   False                  Dresden  Oct19
# 4          apartment      3.0   False                   Bremen  Feb20
# 6                NaN      2.0    True      Mittelsachsen_Kreis  Feb20
# 7       ground_floor      3.0   False                   Bremen  Feb20
# ...              ...      ...     ...                      ...    ...
# 268844   roof_storey      3.0   False                    Essen  Feb20
# 268845   roof_storey      3.0   False  Weilheim_Schongau_Kreis  Feb20
# 268846     apartment      3.5   False         Bergstraße_Kreis  May19
# 268847     apartment      4.0    True   Limburg_Weilburg_Kreis  Feb20
# 268848     apartment      2.0   False                     Köln  May19
#
# [228333 rows x 15 columns]

# %%
data.to_csv("heat_map.csv", index=False)
